# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
RIN_PSD_o=(1e-4)**2*(1+(0.1e-3/freq)**2)
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
plt.style.use('bmh')
plt.plot(freq, RIN_PSD_o, 'r-',label = "S_RIN=10^(-4)/√Hz √(1+(0.1mHz/f)^2): Initial")
plt.plot(freq, RIN_PSD_n, 'b-',label = "S_RIN=10^(-4)/√Hz √(1+0.5mHz/f): Proposed")
plt.yscale("log")
plt.xscale("log")
plt.title("RIN in the LISA Band PSD")
plt.xlabel("Frequency (Hz)")
plt.ylabel("RIN (1/(Hz)")
plt.legend(title = "PSD")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
RIN_ASD_o=(1e-4)*(1+(0.1e-3/freq)**2)**0.5
RIN_ASD_n=(1e-4)*(1+(0.5e-3/freq))**0.5
plt.style.use('bmh')
plt.plot(freq, RIN_ASD_o, 'r-',label = "S_RIN=10^(-4)/√Hz √(1+(0.1mHz/f)^2): Initial")
plt.plot(freq, RIN_ASD_n, 'b-',label = "S_RIN=10^(-4)/√Hz √(1+0.5mHz/f): Proposed")
plt.yscale("log")
plt.xscale("log")
plt.title("RIN in the LISA Band ASD")
plt.xlabel("Frequency (Hz)")
plt.ylabel("RIN (1/(sqrtHz)")
plt.legend(title = "ASD")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
#units of kg
Mass=1.92
#speed of light in m/s
C=299792458.0
#Incident circularly polarized beam power in Watts
Power=0.001
RIN_PSD_o=(1e-4)**2*(1+(0.1e-3/freq)**2)
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
LaserPressureNoise_o=(1/Mass**2*RIN_PSD_o*4.*Power**2/C**2)**0.5
LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
Allocation=((1e-15)**2*(1e-4/freq)**2 + (0.5e-15)**2)**0.5
plt.style.use('bmh')
# plot lines 
plt.plot(freq, LaserPressureNoise_o,'r-', label = "PressureNoise_old")
plt.plot(freq, LaserPressureNoise_n,'b-', label = "PressureNoise_new")
plt.plot(freq, Allocation,'k--', label = "Allocation") 
#plt.plot(freq, Allocation,'b-', label = "Allocation") 
plt.yscale("log")
plt.xscale("log")
#plt.title("LaserPressureNoise")
plt.xlabel("Frequency (Hz)")
#plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz) | Allocation(m/s^2/Hz)")
plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)") 
# Add a title to a legend 
plt.legend(title = "To TM Acc Noise") 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
#units of kg
Mass=1.92
#speed of light in m/s
C=299792458.0
#Incident circularly polarized beam power in Watts
Power=0.001
RIN_PSD_o=(1e-4)**2*(1+(0.1e-3/freq)**2)
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
RIN_PSD_n2=(1e-4)**2*(1+(0.5e-3/freq)**2)
LaserPressureNoise_o=(1/Mass**2*RIN_PSD_o*4.*Power**2/C**2)**0.5
LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
LaserPressureNoise_n2=(1/Mass**2*RIN_PSD_n2*4.*Power**2/C**2)**0.5
LaserPressureNoise_6=(1/Mass**2*RIN_PSD_6*4.*Power**2/C**2)**0.5
Allocation=((1e-15)**2*(1e-4/freq)**2 + (0.5e-15)**2)**0.5
plt.style.use('bmh')
# plot lines 
plt.plot(freq, LaserPressureNoise_o,'r-', label = "PressureNoise sqrt(1+0.1/f^2)")
plt.plot(freq, LaserPressureNoise_n,'b-', label = "PressureNoise sqrt(1+0.5/f)")
plt.plot(freq, LaserPressureNoise_n2,'r--', label = "PressureNoise sqrt(1+0.5/f^2)")
plt.plot(freq, LaserPressureNoise_6,'g--.', label = "PressureNoise sqrt(1+0.6/f)")
plt.plot(freq, Allocation,'k-', label = "Allocation")
plt.yscale("log")
plt.xscale("log")
#plt.title("LaserPressureNoise")
plt.xlabel("Frequency (Hz)")
plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz) | Allocation(m/s^2/Hz)")
#plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)") 
# Add a title to a legend 
plt.legend(title = "To TM Acc Noise") 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
#units of kg
Mass=1.92
#speed of light in m/s
C=299792458.0
#Incident circularly polarized beam power in Watts
Power=0.001
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
RIN_PSD_n2=(1e-4)**2*(1+(0.5e-3/freq)**2)
LaserPressureNoise_p29=(1/Mass**2*RIN_PSD_p29*4.*Power**2/C**2)**0.5
LaserPressureNoise_p2=(1/Mass**2*RIN_PSD_p2*4.*Power**2/C**2)**0.5
LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
LaserPressureNoise_n2=(1/Mass**2*RIN_PSD_n2*4.*Power**2/C**2)**0.5
LaserPressureNoise_6=(1/Mass**2*RIN_PSD_6*4.*Power**2/C**2)**0.5
Allocation=((1e-15)**2*(1e-4/freq)**2 + (0.5e-15)**2)**0.5
plt.style.use('bmh')
# plot lines 
plt.plot(freq, LaserPressureNoise_p2,'b-', label = "PressureNoise sqrt(1+0.2/f^2)")
#plt.plot(freq, LaserPressureNoise_n,'b-', label = "PressureNoise sqrt(1+0.5/f)")
#plt.plot(freq, LaserPressureNoise_n2,'r--', label = "PressureNoise sqrt(1+0.5/f^2)")
plt.plot(freq, LaserPressureNoise_6,'g-', label = "PressureNoise sqrt(1+0.6/f)")
plt.plot(freq, Allocation,'k-', label = "Allocation")
plt.yscale("log")
plt.xscale("log")
#plt.title("LaserPressureNoise")
plt.xlabel("Frequency (Hz)")
plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz) | Allocation(m/s^2/Hz)")
#plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)") 
# Add a title to a legend 
plt.legend(title = "To TM Acc Noise") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      11 RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
#      12 RIN_PSD_n2=(1e-4)**2*(1+(0.5e-3/freq)**2)
# ---> 13 LaserPressureNoise_p29=(1/Mass**2*RIN_PSD_p29*4.*Power**2/C**2)**0.5
#      14 LaserPressureNoise_p2=(1/Mass**2*RIN_PSD_p2*4.*Power**2/C**2)**0.5
#      15 LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
#
# NameError: name 'RIN_PSD_p29' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00001, 1, 30000)
#units of kg
Mass=1.92
#speed of light in m/s
C=299792458.0
#Incident circularly polarized beam power in Watts
Power=0.001
RIN_PSD_p1=(1e-4)**2*(1+(0.1e-3/freq)**2)
RIN_PSD_p2=(1e-4)**2*(1+(0.2e-3/freq)**2)
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
RIN_PSD_n2=(1e-4)**2*(1+(0.5e-3/freq)**2)
LaserPressureNoise_p1=(1/Mass**2*RIN_PSD_p1*4.*Power**2/C**2)**0.5
LaserPressureNoise_p2=(1/Mass**2*RIN_PSD_p2*4.*Power**2/C**2)**0.5
LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
LaserPressureNoise_n2=(1/Mass**2*RIN_PSD_n2*4.*Power**2/C**2)**0.5
LaserPressureNoise_6=(1/Mass**2*RIN_PSD_6*4.*Power**2/C**2)**0.5
Allocation=((1e-15)**2*(1e-4/freq)**2 + (0.5e-15)**2)**0.5
plt.style.use('bmh')
# plot lines 
plt.plot(freq, LaserPressureNoise_p1,'r-', label = "PressureNoise sqrt(1+0.1/f^2) Initial")
plt.plot(freq, LaserPressureNoise_p2,'b--', label = "PressureNoise sqrt(1+0.2/f^2) Option")
plt.plot(freq, LaserPressureNoise_n,'b-', label = "PressureNoise sqrt(1+0.5/f) Proposed")
#plt.plot(freq, LaserPressureNoise_n2,'r--', label = "PressureNoise sqrt(1+0.5/f^2)")
#plt.plot(freq, LaserPressureNoise_6,'g-', label = "PressureNoise sqrt(1+0.6/f)")
plt.plot(freq, Allocation,'k-', label = "Allocation")
plt.yscale("log")
plt.xscale("log")
#plt.title("LaserPressureNoise")
plt.xlabel("Frequency (Hz)")
plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)")
#plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)") 
# Add a title to a legend 
plt.legend(title = "To TM Acc Noise") 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
freq = np.linspace(0.00002, 1, 30000)
#units of kg
Mass=1.92
#speed of light in m/s
C=299792458.0
#Incident circularly polarized beam power in Watts
Power=0.001
RIN_PSD_p1=(1e-4)**2*(1+(0.1e-3/freq)**2)
RIN_PSD_p2=(1e-4)**2*(1+(0.2e-3/freq)**2)
RIN_PSD_n=(1e-4)**2*(1+(0.5e-3/freq))
RIN_PSD_6=(1e-4)**2*(1+(0.6e-3/freq))
RIN_PSD_n2=(1e-4)**2*(1+(0.5e-3/freq)**2)
LaserPressureNoise_p1=(1/Mass**2*RIN_PSD_p1*4.*Power**2/C**2)**0.5
LaserPressureNoise_p2=(1/Mass**2*RIN_PSD_p2*4.*Power**2/C**2)**0.5
LaserPressureNoise_n=(1/Mass**2*RIN_PSD_n*4.*Power**2/C**2)**0.5
LaserPressureNoise_n2=(1/Mass**2*RIN_PSD_n2*4.*Power**2/C**2)**0.5
LaserPressureNoise_6=(1/Mass**2*RIN_PSD_6*4.*Power**2/C**2)**0.5
Allocation=((1e-15)**2*(1e-4/freq)**2 + (0.5e-15)**2)**0.5
plt.style.use('bmh')
# plot lines 
plt.plot(freq, LaserPressureNoise_p1,'r-', label = "S_RIN=10^(-4)/√Hz √(1+(0.1mHz/f)^2): Initial", linewidth=1.5)
plt.plot(freq, LaserPressureNoise_p2,'b--', label = "S_RIN=10^(-4)/√Hz √(1+(0.2mHz/f)^2): Option", linewidth=1.5)
plt.plot(freq, LaserPressureNoise_n,'b-', label = "S_RIN=10^(-4)/√Hz √(1+0.5mHz/f): Proposed", linewidth=1.5)
#plt.plot(freq, LaserPressureNoise_n2,'r--', label = "PressureNoise sqrt(1+0.5/f^2)", linewidth=1.5)
#plt.plot(freq, LaserPressureNoise_6,'g-', label = "PressureNoise sqrt(1+0.6/f)", linewidth=1.5)
plt.plot(freq, Allocation,'k-', label = "Allocation", linewidth=1.5)
plt.yscale("log")
plt.xscale("log")
plt.xlim(1e-5, 1)
#plt.title("LaserPressureNoise")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Laser Pressure Noise (m/s/s/√Hz)")
#plt.ylabel("LaserPressureNoise(m/s^2/sqrt(Hz)") 
# Add a title to a legend 
plt.grid(visible=None, which='minor', axis='both')
plt.legend(title = "Laser Pressure Noise corresponding to") 
plt.show()
